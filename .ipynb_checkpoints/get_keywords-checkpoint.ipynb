# %%
import platform
print (platform.architecture ())
# Out:
# ('64bit', 'WindowsPE')

# %%
import requests
from copy import copy


def dfs(category_id):
    url = "https://api.itemscout.io/api/category/{0}/subcategories".format(category_id)
    response = requests.get(url = url)
    
    for d in response.json()['data']:

        d_id = d['id']
        d_name = d['name']
        d_is_leaf = d['is_leaf']
        
        if(d_is_leaf):
            leaf_id = copy(d_id)
            leaf_name = copy(d_name)
            leaf_category.append([leaf_id,leaf_name])
            
        else:
            dfs(d_id)
    
paths = []
leaf_category = []
starting_category = [1,2,3,4,5,8,9] #출산/육아(6) , 식품 제외(7)


first_category = [1]

for category in first_category:
    dfs(category)



print(len(leaf_category))
#1 : 패션의류 --> 68개 
#2 : 패션잡화 --> 264개
#3 : 화장품/미용 --> 157개
#4 : 디지털/가전 --> 681개
#5 : 가구/인테리어 --> 354개
#6 : 출산/육아 (X)
#7 : 식품 (X)
#8 : 스포츠/레저 --> 카테고리 : 480개, 키워드 : 154207개 --> 필터 적용 : 20000개
#9 : 생활/건강 --> 카테고리 : 1227개, 키워드 : 465817개 --> 필터 적용 : 61751개

#app 1개당 기본 api 12500개 
#계정 1개당 app 10개, api 125000개
# Out:
# 68

# %%
import json
import urllib.request
from collections import OrderedDict
from tqdm import notebook
from joblib import Parallel, delayed
from time import sleep
from config import *
from infsell import *



def extract_titles(category,client_auth):
    
    category_id = category[0]
    category_name = category[1]
    
    url_data = "https://api.itemscout.io/api/category/{0}/data".format(category_id)
    url_brands = "https://api.itemscout.io/api/category/{0}/brands".format(category_id)
    while True:	
        try: 
            response_data = requests.post(url_data, json=PAYLOAD)
            break
        except Exception as e:
            print(e)
            pass
    response_brands = requests.get(url_brands)
    data = response_data.json()['data']['data']
    brands = response_brands.json()['data']
    brands = remove_a_word(brands)
    
    keywords = get_keywords_database(data)
    keywords_nb = remove_brands(keywords,brands)
    
    for keyword in keywords_nb[:5]:
        encText = urllib.parse.quote(keyword)
        url_items = "https://openapi.naver.com/v1/search/shop.json?display=80&query=" + encText # JSON 결과
        titles = []
        
        try:
            items = get_items(url_items,client_auth)
            
            for item in items:
                title = item['title'].replace('<b>','').replace('</b>','')
                titles.append(title)
            
            info_keyword={}
            info_keyword['category'] = category_name
            info_keyword['keyword'] = keyword
            info_keyword['titles'] = titles

            titles_data.append(info_keyword)

        except Exception as e:
            print('error ',e, ' 키워드 : ', keyword)
            pass
            
       
        

#멀티코어 개수
num_core = 12

cnt_keyword=0
path_auth='auth_api.txt'
client_auth = get_auth_api(path_auth)
titles_data = [] 

with Parallel(n_jobs=num_core, require='sharedmem') as parallel:
    parallel(delayed(extract_titles)(category,client_auth)for category in notebook.tqdm(leaf_category[:1]))
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
 모달 블라우스 3종', '폭신폭신 스퀘어넥 퍼프소매 프릴 블라우스', '톰보이 루즈핏블라우스 9173221982', '지컷 23 S S아일렛 레이스 코튼 블라우스 7253260106', '쉬즈미스 블라우스 SWWBLM22070', '리스트 벨티드 페플럼 블라우스 TWWBLM62040', '여성 반팔 셔츠 여름남방 시어서커 블라우스 아사면 지지미 스트라이프셔츠', '쉬즈미스 블라우스 SWWBLM21010', '여름 긴팔 셔츠 블라우스 여성린넨셔츠', '블라우스맛집 여름 펀칭 퍼프 셔링 린넨 반팔블라우스 아이보리', '빅사이즈 엄마옷 여름 인견 7부 블라우스', '리스트 린넨 개더 퍼프 블라우스 TWWBLN62120', '23SS 롤리팝 블라우스 소매 퍼프 캔디 벌룬 엠보 반팔 블라우스', '모조로브 빅카라 면체크 지지미 반팔블라우스', '플라스틱아일랜드 V넥 레이스 단추 반팔 블라우스 PNTWB042', '쉬즈미스 퍼프 반팔 블라우스 SWWSTN22010', '여름 플레어 링클 지지미 크롭 블라우스 a라인 화이트 노란색 여성 티블라우스', '리스트 체크 패턴 핀턱 블라우스 TWWBLM60020', '플라스틱아일랜드 블라우스 PP2WB583', '루시앙 인견 100 썸머 블라우스 3종 SET', '리스트 스퀘어넥 반팔 블라우스 TWWBLN62090', '써스데이아일랜드 여성 레터링 포인트 블라우스 T214MBL255W', '지컷 스퀘어넥 셔링 블라우스 D 7293260101', '써스데이아일랜드 크롭 플레어 블라우스 T234MBL302', '주크 펀칭 반팔 블라우스 RB2BL002', '지지미 블라우스(10일소요)6차물량', '리스트 퍼프 브이넥 블라우스 TWWBLN62110', '퍼프 소매 라운드 반팔 블라우스 화이트 하늘색 블랙 봄 여름', '벨 와이드 스퀘어넥 자수 블라우스', '[그레이시크] 바스락퍼프블라우스', '쉬즈미스 NC02 러플 카라 블라우스 SWWBLM21100', '[르베스티어] [르베스티어] 23SS  ...

# %%
while True:
    try :
        with open('database.json', 'r', encoding='utf-8') as f:
            data = json.load(f)
    
    except :
        with open('test3.json', 'w',encoding='utf-8') as f:
            f.write(json.dumps(titles_data, ensure_ascii=False,indent=4))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 with open('database.json', 'r', encoding='utf-8') as f:
#       2     after = json.load(f)
#
# File c:\users\ahoho\pycharmprojects\keyword\venv\lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'database.json'

# %%
path_database = "database6.json"

with open(path_database, 'w',encoding='utf-8') as f:
    f.write(json.dumps(titles_data, ensure_ascii=False,indent=4))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[4], line 3
#       1 path_database = "database6.json"
#       2 with open(path_database, 'w',encoding='utf-8') as f:
# ----> 3     f.write(json.dumps(titles_data, ensure_ascii=False,indent=4))
#
# File C:\Python38\lib\json\__init__.py:234, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
# --> 234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
#     238     **kw).encode(obj)
#
# File C:\Python38\lib\json\encoder.py:202, in JSONEncoder.encode(self, o)
#     200 if not isinstance(chunks, (list, tuple)):
#     201     chunks = list(chunks)
# --> 202 return ''.join(chunks)
#
# MemoryError:

# %%
with open('database5.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# %%
print(len(data))
